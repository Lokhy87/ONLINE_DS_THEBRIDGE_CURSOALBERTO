# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %% [markdown]
# ## "Los Campeones del Grand Slam: Hombres que Dominan el Tenis Mundial"

# %% [markdown]
# ### TEMA

# %% [markdown]
# ### "Analisis de los resultados en tenis masculino en los cuatro torneos mas importantes de la ATP."

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %% [markdown]
# #### Los ganadores de siempre se encuentran en el top 10 de la ATP.

# %% [markdown]
# ##### El ganador en una superficie es el ganador en otra diferente.
# ##### El ganador de un año repite el siguiente año como ganador o finalista.
# ##### El ganador de un Master 1000 es el ganador de un Grand Slam de la misma superficie.

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd
# guarda en variables los datasets y su fuente
df_1 = pd.read_csv("./data/Mens_Tennis_Grand_Slam_Winner.csv")
fuente_1 = "https://www.kaggle.com/datasets/wonduk/mens-tennis-grand-slam-winner-dataset"
df_2 = pd.read_csv("./data/atp_ranking.csv")
fuente_2 = "https://www.kaggle.com/datasets/isaienkov/atp-ranking/data"
df_3 = pd.read_csv("./data/atp_matches_qual_chall_2020.csv")
fuente_3 = "https://www.kaggle.com/datasets/kalilurrahman/atp-tennis-player-ranking-dataset?rvi=1"

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Ganadores de los 4 Grand slam 
df_1.head(5)
# Out:
#    YEAR       TOURNAMENT          WINNER           RUNNER-UP  \
# 0  2023  Australian Open  Novak Djokovic  Stefanos Tsitsipas
# 1  2022        U.S. Open  Carlos Alcaraz         Casper Rudd
# 2  2022        Wimbledon  Novak Djokovic        Nick Kyrgios
# 3  2022      French Open    Rafael Nadal         Casper Rudd
# 4  2022  Australian Open    Rafael Nadal     Daniil Medvedev
#
#   WINNER_NATIONALITY  WINNER_ATP_RANKING  RUNNER-UP_ATP_RANKING  \
# 0            Serbian                 1.0                    3.0
# 1            Spanish                 2.0                    5.0
# 2            Serbian                 NaN                   25.0
# 3            Spanish                 5.0                    8.0
# 4            Spanish                 5.0                    2.0
#
#   WINNER_LEFT_OR_RIGHT_HANDED     TOURNAMENT_SURFACE  WINNER_PRIZE
# 0                       right  Plexicushion Prestige     2050000.0
# 1                       right    DecoTurf - outdoors     2600000.0
# ...

# %%
# Ranking ATP
df_2.head(5)
# Out:
#    rank               player country  total_points  grand_slam_points  \
# 0     1      Alcaraz, Carlos     ESP          6820               2450
# 1     2        Nadal, Rafael     ESP          6020               4180
# 2     3         Ruud, Casper     NOR          5820               2400
# 3     4  Tsitsipas, Stefanos     GRE          5550                910
# 4     5      Djokovic, Novak     SRB          4820                360
#
#    masters_points  other_points  tournaments
# 0            2740          1630           17
# 1             890           950           14
# 2            1565          1855           23
# 3            3065          1575           23
# 4            1970          2490           14

# %%
# Qually 
df_3.head(5)
# Out:
#   tourney_id tourney_name surface  draw_size tourney_level  tourney_date  \
# 0  2020-0451         Doha    Hard         32             A      20200106
# 1  2020-0451         Doha    Hard         32             A      20200106
# 2  2020-0451         Doha    Hard         32             A      20200106
# 3  2020-0451         Doha    Hard         32             A      20200106
# 4  2020-0451         Doha    Hard         32             A      20200106
#
#    match_num  winner_id  winner_seed winner_entry  ... l_1stIn l_1stWon  \
# 0        254     105916          1.0          NaN  ...    48.0     30.0
# 1        253     144707          2.0          NaN  ...    58.0     34.0
# 2        252     106296          3.0          NaN  ...    51.0     34.0
# 3        251     144895          4.0          NaN  ...    30.0     15.0
# 4        250     105916          1.0          NaN  ...    65.0     45.0
#
#    l_2ndWon l_SvGms  l_bpSaved  l_bpFaced  winner_rank winner_rank_points  \
# ...
