# %%
import cv2
import keras
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
import seaborn as sns
import random

# %%
data = pd.read_csv('./data/fictional_character_battles_complex.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2351 entries, 0 to 2350
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Character         2351 non-null   object
#  1   Universe          2351 non-null   object
#  2   Strength          2351 non-null   int64
#  3   Speed             2351 non-null   int64
#  4   Intelligence      2351 non-null   int64
#  5   SpecialAbilities  2351 non-null   object
#  6   Weaknesses        2351 non-null   object
#  7   BattleOutcome     2351 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 147.1+ KB

# %%
data.head()
# Out:
#       Character   Universe  Strength  Speed  Intelligence SpecialAbilities  \
# 0  Wonder Woman     Marvel         7      8             3      Telekinesis
# 1      Iron Man     Marvel         4      7             9      Telekinesis
# 2      Iron Man  DC Comics         8      7             5      Telekinesis
# 3    Spider-Man  DC Comics         5      6            10      Telekinesis
# 4         Flash     Marvel         7      6             2     Invisibility
#
#    Weaknesses  BattleOutcome
# 0  Kryptonite              0
# 1  Kryptonite              0
# 2       Magic              0
# 3  Kryptonite              0
# 4       Magic              0

# %%
df1 = pd.read_csv('./data/charcters_stats.csv')
df1.head()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 611 entries, 0 to 610
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Name          611 non-null    object
#  1   Alignment     608 non-null    object
#  2   Intelligence  611 non-null    int64
#  3   Strength      611 non-null    int64
#  4   Speed         611 non-null    int64
#  5   Durability    611 non-null    int64
#  6   Power         611 non-null    int64
#  7   Combat        611 non-null    int64
#  8   Total         611 non-null    int64
# dtypes: int64(7), object(2)
# memory usage: 43.1+ KB

# %%
df1_2 = pd.read_csv('./data/marvelvsdc.csv')
df1_2.head()
# Out:
#    Unnamed: 0            title  year                      genre  runtime  \
# 0           1  Captain America  1944  Action, Adventure, Sci-Fi      244
# 1           2  Howard the Duck  1986  Action, Adventure, Comedy      110
# 2           3            Blade  1998     Action, Horror, Sci-Fi      120
# 3           4            X-Men  2000  Action, Adventure, Sci-Fi      104
# 4           5         Blade II  2002    Action, Fantasy, Horror      117
#
#   mpa_rating  imdb_rating  imdb_votes  imdb_gross            director  \
# 0   Approved          5.5         844           0       Elmer Clifton
# 1         PG          4.7       44073    16300000       Willard Huyck
# 2          R          7.1      251243    70090000  Stephen Norrington
# 3      PG-13          7.4      580354   157300000        Bryan Singer
# 4          R          6.7      203813    82350000  Guillermo del Toro
#
#                                                stars  \
# ...

# %%
df1_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      90 non-null     int64
#  1   title           90 non-null     object
#  2   year            90 non-null     int64
#  3   genre           90 non-null     object
#  4   runtime         90 non-null     int64
#  5   mpa_rating      90 non-null     object
#  6   imdb_rating     90 non-null     float64
#  7   imdb_votes      90 non-null     int64
#  8   imdb_gross      90 non-null     int64
#  9   director        90 non-null     object
#  10  stars           90 non-null     object
#  11  description     90 non-null     object
#  12  crit_consensus  90 non-null     object
#  13  tomato_meter    90 non-null     int64
#  14  tomato_review   90 non-null     int64
#  15  tom_aud_score   90 non-null     int64
#  16  tom_ratings     90 non-null     int64
# ...

# %%
df_snap1 = pd.read_csv('./data/marvel_snap_zone/cards.csv')
df_snap1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 274 entries, 0 to 273
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   cid            274 non-null    int64
#  1   name           274 non-null    object
#  2   cost           274 non-null    int64
#  3   power          274 non-null    int64
#  4   ability        261 non-null    object
#  5   flavor         13 non-null     object
#  6   art            274 non-null    object
#  7   alternate_art  0 non-null      float64
#  8   url            274 non-null    object
#  9   status         274 non-null    object
#  10  carddefid      274 non-null    object
#  11  variants       274 non-null    object
#  12  source         234 non-null    object
#  13  source_slug    234 non-null    object
#  14  tags           274 non-null    object
#  15  rarity         0 non-null      float64
#  16  rarity_slug    0 non-null      float64
# ...

# %%
df_snap1.head()
# Out:
#    cid             name  cost  power  \
# 0    1      Abomination     5      9
# 1    2    Absorbing Man     4      4
# 2    3     Adam Warlock     2      0
# 3    4             Aero     5      8
# 4    5  Agatha Harkness     6     14
#
#                                              ability  \
# 0                                                NaN
# 1  <span>On Reveal</span>: If the last card you p...
# 2  At the end of each turn, if you are winning th...
# 3  <span>On Reveal</span>: Move the last enemy ca...
# 4  Agatha starts in your hand and plays your card...
#
#                                   flavor  \
# 0  "Foolish rabble! You are beneath me!"
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
#
#                                                  art  alternate_art  \
# 0  https://marvelsnapzone.com/wp-content/themes/b...            NaN
# ...

# %%
df_snap1.columns
# Out:
# Index(['cid', 'name', 'cost', 'power', 'ability', 'flavor', 'art',
#        'alternate_art', 'url', 'status', 'carddefid', 'variants', 'source',
#        'source_slug', 'tags', 'rarity', 'rarity_slug', 'difficulty',
#        'sketcher', 'inker', 'colorist'],
#       dtype='object')

# %%
df_snap1_2 = pd.read_csv('./data/marvel_snap_zone/decks.csv')
df_snap1_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9790 entries, 0 to 9789
# Data columns (total 13 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   did              9790 non-null   object
#  1   user             9788 non-null   object
#  2   name             9790 non-null   object
#  3   url              9790 non-null   object
#  4   description      0 non-null      float64
#  5   cids             9790 non-null   object
#  6   avg_power        9790 non-null   float64
#  7   avg_cost         9790 non-null   float64
#  8   total_likes      9790 non-null   int64
#  9   tags             0 non-null      float64
#  10  lastup           9790 non-null   int64
#  11  collection_date  9790 non-null   object
#  12  last_update      9790 non-null   object
# dtypes: float64(4), int64(2), object(7)
# memory usage: 994.4+ KB

# %%
df_snap1_2.head()
# Out:
#                    did           user            name  \
# 0  0063hx6trj2ryp2mow0         cristu       ANTI LOKI
# 1  0064xs4d2yyb1mqn1zm        leporte  StandardBounce
# 2  006e83cllqj97f51msg          zequi   surfer thanos
# 3  00a6jqlchdxttyv53cs  king_zordland    shuri-sauron
# 4  00djp9i3usufdwb62xw     sevillacrx      Jeff Kitty
#
#                                                  url  description  \
# 0  https://marvelsnapzone.com/decks/anti-loki-8bdrs/          NaN
# 1  https://marvelsnapzone.com/decks/standardbounc...          NaN
# 2  https://marvelsnapzone.com/decks/surfer-thanos...          NaN
# 3  https://marvelsnapzone.com/decks/shuri-sauron-...          NaN
# 4  https://marvelsnapzone.com/decks/jeff-kitty-cm...          NaN
#
#                                                 cids  avg_power  avg_cost  \
# 0  [261, 446, 157, 409, 239, 281, 8, 5, 87, 61, 2...        9.2       5.5
# 1  [262, 120, 380, 104, 10, 261, 80, 171, 21, 99,...        1.9       2.3
# ...

# %%
df_snapro1 = pd.read_csv('./data/marvel_snap_pro/cards.csv')
df_snapro1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233 entries, 0 to 232
# Data columns (total 34 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   cardid                 233 non-null    object
#  1   carddefid              233 non-null    object
#  2   name                   233 non-null    object
#  3   description            233 non-null    object
#  4   abilities              218 non-null    object
#  5   cost                   233 non-null    int64
#  6   power                  233 non-null    int64
#  7   category               166 non-null    object
#  8   source                 233 non-null    object
#  9   use_count              233 non-null    int64
#  10  connected_cards        233 non-null    object
#  11  PrimaryColor           233 non-null    object
#  12  SecondaryColor         233 non-null    object
#  13  RingColor              233 non-null    object
# ...

# %%
df_snapro1_2 = pd.read_csv('./data/marvel_snap_pro/decks.csv')
df_snapro1_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18315 entries, 0 to 18314
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              18315 non-null  object
#  1   author            18315 non-null  int64
#  2   authornick        5020 non-null   object
#  3   date              18315 non-null  object
#  4   date_edited       18315 non-null  int64
#  5   slug              18315 non-null  object
#  6   humanname         18315 non-null  object
#  7   atid              1663 non-null   float64
#  8   archetype         1663 non-null   object
#  9   supertype         1663 non-null   object
#  10  tags              13262 non-null  object
#  11  youtube           824 non-null    object
#  12  views             18315 non-null  int64
#  13  public_wins       10744 non-null  float64
#  14  public_loss       10744 non-null  float64
#  15  public_cube_wins  10744 non-null  float64
# ...

# %%
df_snapro1_2.head()
# Out:
#          name  author            authornick                 date  date_edited  \
# 0  2ny9s4rxo1  402605  Johan Hansen Saragih  2023-10-01 11:50:49   1696175449
# 1  n7x1dhkmhm  402605  Johan Hansen Saragih  2023-10-01 11:50:49   1696175449
# 2   8lp6a91eo  402605  Johan Hansen Saragih  2023-10-01 11:50:49   1696175449
# 3  abzkoa7jgq  402605  Johan Hansen Saragih  2023-10-01 11:50:49   1696175449
# 4  d60mf9dd9p  402605  Johan Hansen Saragih  2023-10-01 11:50:49   1696175449
#
#                  slug     humanname  atid         archetype       supertype  \
# 0   thanos-deck-to2dd  Thanos Deck    NaN               NaN             NaN
# 1        combine-deck  Combine Deck   NaN               NaN             NaN
# 2  discard-deck-2urqe  Discard Deck   4.0      Discard Hela         Discard
# 3    leech-deck-4b942   Leech Deck   94.0  Control Infinaut  Increase Power
# 4         2-card-deck   2 Card Deck   NaN               NaN             NaN
#
# ...

# %%
df_comic = pd.read_csv('./data/Marvel_Comics.csv')
df_comic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34992 entries, 0 to 34991
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   comic_name         34992 non-null  object
#  1   active_years       34992 non-null  object
#  2   issue_title        34466 non-null  object
#  3   publish_date       34466 non-null  object
#  4   issue_description  30395 non-null  object
#  5   penciler           25482 non-null  object
#  6   writer             27595 non-null  object
#  7   cover_artist       12255 non-null  object
#  8   Imprint            11684 non-null  object
#  9   Format             32894 non-null  object
#  10  Rating             12619 non-null  object
#  11  Price              32894 non-null  object
# dtypes: object(12)
# memory usage: 3.2+ MB

# %%
df_comic.head()
# Out:
#                                           comic_name active_years  \
# 0     A Year of Marvels: April Infinite Comic (2016)       (2016)
# 1    A Year of Marvels: August Infinite Comic (2016)       (2016)
# 2  A Year of Marvels: February Infinite Comic (2016)       (2016)
# 3      A Year of Marvels: July Infinite Comic (2016)       (2016)
# 4      A Year of Marvels: June Infinite Comic (2016)       (2016)
#
#                                          issue_title       publish_date  \
# 0  A Year of Marvels: April Infinite Comic (2016) #1     April 01, 2016
# 1  A Year of Marvels: August Infinite Comic (2016...    August 10, 2016
# 2  A Year of Marvels: February Infinite Comic (20...  February 10, 2016
# 3   A Year of Marvels: July Infinite Comic (2016) #1      June 29, 2016
# 4   A Year of Marvels: June Infinite Comic (2016) #1      June 15, 2016
#
#                                    issue_description  \
# 0  The Infinite Comic that will have everyone tal...
# ...

# %% [markdown]
# Star wars

# %%
df_SW = pd.read_csv('./data/csv/weapons.csv')
df_SW.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60 entries, 0 to 59
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               60 non-null     int64
#  1   name             60 non-null     object
#  2   model            60 non-null     object
#  3   manufacturer     60 non-null     object
#  4   cost_in_credits  33 non-null     float64
#  5   length           55 non-null     float64
#  6   type             60 non-null     object
#  7   description      60 non-null     object
#  8   films            60 non-null     object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 4.3+ KB

# %%
df_SW.head()
# Out:
#    id              name                           model  \
# 0   1       Snowspeeder                 t-47 airspeeder
# 1   2       TIE Fighter  Twin Ion Engine/Ln Starfighter
# 2   3      Sand Crawler                  Digger Crawler
# 3   4  X-34 Landspeeder                X-34 Landspeeder
# 4   5        TIE Bomber                   TIE/sa Bomber
#
#                   manufacturer  cost_in_credits  length  \
# 0            Incom corporation              0.0     4.5
# 1         Sienar Fleet Systems          75000.0     6.3
# 2  Corellia Mining Corporation         150000.0    36.8
# 3         SoroSuub Corporation          10550.0     3.4
# 4         Sienar Fleet Systems          86500.0     7.8
#
#    max_atmosphering_speed  crew  passengers  cargo_capacity consumables  \
# 0                   650.0     2           0            10.0        none
# 1                  1200.0     1           0            65.0      2 days
# ...
